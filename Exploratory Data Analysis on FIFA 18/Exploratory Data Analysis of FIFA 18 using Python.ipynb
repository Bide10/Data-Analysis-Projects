# %% [markdown]
# # ⚽️⚽️⚽️⚽️⚽️Exploratory Data Analysis of FIFA 18 using Python⚽️⚽️⚽️⚽️⚽️
#
# <img src="https://static0.gamerantimages.com/wordpress/wp-content/uploads/fifa-18-trailer-ronaldo-cover-art.jpg" alt="FIFA 18" />

# %% [markdown]
# # Introduction ⚽️🏃‍♂️
#
# FIFA along with gaming studio EA Sports created a series of games named FIFA. This franchise started from FIFA95, the first edition of this gaming franchise till FIFA 23 the latest edition after which their partnership ended. Now they are going to create this legendary football game series separately.
#
#
#
# Here I have taken the dataset for FIFA 18 the 2018 edition of the game and analysed it to find interesting insights. How are the wages and ages of players related? What factors contribute to a player's overall rating or market value? I combined my love for football and data science to whip up a short exploratory analysis of the FIFA 18 dataset using Python.

# %% [markdown]
# ## Step 0 : Importing libraries 📚 and Reading Dataset

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pylab as plt 
import seaborn as sns 
plt.style.use('ggplot')
#pd.set_option('max_columns',100)

# %%
df = pd.read_csv('fifa18_clean - fifa18_clean.csv')
df
# Out:
#        Wage (€)  Value (€)               Name  Age  \
# 0        565000   95500000  Cristiano Ronaldo   32
# 1        565000  105000000           L. Messi   30
# 2        280000  123000000             Neymar   25
# 3        510000   97000000          L. Suárez   30
# 4        230000   61000000           M. Neuer   31
# ...         ...        ...                ...  ...
# 17976      1000      50000          A. Kelsey   17
# 17977      1000          0      B. Richardson   47
# 17978      1000      60000           J. Young   17
# 17979      1000      60000       J. Lundstram   18
# 17980      1000      50000          L. Sackey   18
#
#                                                  Photo Nationality  \
# 0       https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1      https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2      https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3      https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# ...

# %% [markdown]
# ## Step 1: Understanding Data

# %%
# to check the dimensions of the dataset
df.shape
# Out:
# (17981, 74)

# %%
df.sample(5)
# Out:
#        Wage (€)  Value (€)             Name  Age  \
# 2737      16000    3000000     S. Pocognoli   29
# 1722       1000    7500000     André Simões   27
# 5625      32000    3800000  Matheus Pereira   19
# 10203      3000     160000          R. Vera   34
# 2821      14000    3500000    Fabiano Sonta   25
#
#                                                  Photo Nationality  \
# 2737   https://cdn.sofifa.org/48/18/players/163369.png     Belgium
# 1722   https://cdn.sofifa.org/48/18/players/224075.png    Portugal
# 5625   https://cdn.sofifa.org/48/18/players/229337.png      Brazil
# 10203  https://cdn.sofifa.org/48/18/players/226390.png   Argentina
# 2821   https://cdn.sofifa.org/48/18/players/230218.png      Brazil
#
#                                       Flag  Overall  Potential  \
# 2737    https://cdn.sofifa.org/flags/7.png       73         73
# 1722   https://cdn.sofifa.org/flags/38.png       75         76
# 5625   https://cdn.sofifa.org/flags/54.png       70         85
# ...

# %%
# to see the number of cols.
df.columns
# Out:
# Index(['Wage (€)', 'Value (€)', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Special', 'Acceleration',
#        'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure',
#        'Crossing', 'Curve', 'Dribbling', 'Finishing', 'Free kick accuracy',
#        'GK diving', 'GK handling', 'GK kicking', 'GK positioning',
#        'GK reflexes', 'Heading accuracy', 'Interceptions', 'Jumping',
#        'Long passing', 'Long shots', 'Marking', 'Penalties', 'Positioning',
#        'Reactions', 'Short passing', 'Shot power', 'Sliding tackle',
#        'Sprint speed', 'Stamina', 'Standing tackle', 'Strength', 'Vision',
#        'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'ID', 'LAM', 'LB', 'LCB',
#        'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'Preferred Positions',
#        'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
# to see the info of all the cols or features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 74 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Wage (€)             17981 non-null  int64
#  1   Value (€)            17981 non-null  int64
#  2   Name                 17981 non-null  object
#  3   Age                  17981 non-null  int64
#  4   Photo                17981 non-null  object
#  5   Nationality          17981 non-null  object
#  6   Flag                 17981 non-null  object
#  7   Overall              17981 non-null  int64
#  8   Potential            17981 non-null  int64
#  9   Club                 17733 non-null  object
#  10  Club Logo            17981 non-null  object
#  11  Special              17981 non-null  int64
#  12  Acceleration         17897 non-null  float64
#  13  Aggression           17913 non-null  float64
#  14  Agility              17910 non-null  float64
# ...

# %%
# getting the info and some statistics about the dataset
df.describe()
# Out:
#             Wage (€)     Value (€)           Age       Overall     Potential  \
# count   17981.000000  1.798100e+04  17981.000000  17981.000000  17981.000000
# mean    11546.966242  2.385390e+06     25.144541     66.247984     71.190813
# std     23080.000139  5.353970e+06      4.614272      6.987965      6.102199
# min         0.000000  0.000000e+00     16.000000     46.000000     46.000000
# 25%      2000.000000  3.000000e+05     21.000000     62.000000     67.000000
# 50%      4000.000000  6.750000e+05     25.000000     66.000000     71.000000
# 75%     12000.000000  2.100000e+06     28.000000     71.000000     75.000000
# max    565000.000000  1.230000e+08     47.000000     94.000000     94.000000
#
#             Special  Acceleration    Aggression       Agility       Balance  \
# count  17981.000000  17897.000000  17913.000000  17910.000000  17924.000000
# mean    1594.095100     64.576521     55.791492     63.333613     63.803894
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>From the above table a few things are clear : </b> </br>
#     1. 75% of the players receive a wage of 12000 euros and less, but as we can see max wage is 565000 euros which is way above than 11.5k which is the mean. This is because , top tier players are few in numbers but get super high wages, e.g: Messi , Ronaldo , Neymar etc. are some of those top level players who receive huge salaries. </br>
#     2. Same with the player values , obviously top players have higher market value than majority of the players. </br>
#     3. Overall is the total rating of a player this basically includes all the stats a player has.
#
# </div>

# %% [markdown]
# ## Step 2: Data Preparation ⚙️
# - Dropping irrelevant columns and rows
# - Identifying duplicated columns
# - Renaming Cloumns
# - Feature creation

# %%
# Removing unwanted columns
#subsetting through a list of columns

df.columns
# Out:
# Index(['Wage (€)', 'Value (€)', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Special', 'Acceleration',
#        'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure',
#        'Crossing', 'Curve', 'Dribbling', 'Finishing', 'Free kick accuracy',
#        'GK diving', 'GK handling', 'GK kicking', 'GK positioning',
#        'GK reflexes', 'Heading accuracy', 'Interceptions', 'Jumping',
#        'Long passing', 'Long shots', 'Marking', 'Penalties', 'Positioning',
#        'Reactions', 'Short passing', 'Shot power', 'Sliding tackle',
#        'Sprint speed', 'Stamina', 'Standing tackle', 'Strength', 'Vision',
#        'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'ID', 'LAM', 'LB', 'LCB',
#        'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'Preferred Positions',
#        'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
df = df[['Wage (€)', 'Value (€)', 'Name', 'Age',
    #'Photo', 
    'Nationality', 
    #'Flag',
       'Overall', 'Potential', 'Club', 
    #'Club Logo', 'Special', 'Acceleration',
      # 'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure',
      # 'Crossing', 'Curve', 'Dribbling', 'Finishing', 'Free kick accuracy',
      # 'GK diving', 'GK handling', 'GK kicking', 'GK positioning',
      # 'GK reflexes', 'Heading accuracy', 'Interceptions', 'Jumping',
      # 'Long passing', 'Long shots', 'Marking', 'Penalties', 'Positioning',
      # 'Reactions', 'Short passing', 'Shot power', 'Sliding tackle',
      # 'Sprint speed', 'Stamina', 'Standing tackle', 'Strength', 'Vision',
      # 'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'ID', 'LAM', 'LB', 'LCB',
      # 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'Preferred Positions',
      # 'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST'
   ]].copy()
df.sample(5)
# Out:
#        Wage (€)  Value (€)              Name  Age  Nationality  Overall  \
# 10954     10000     600000        A. Palazzi   21        Italy       64
# 15631      2000     230000      E. Massouema   20       France       58
# 4033      16000    1200000  R. van der Vaart   34  Netherlands       71
# 13184      3000     280000    L. Jeréz Silva   28    Argentina       62
# 5751       5000    1000000        J. Choplin   32       France       70
#
#        Potential                 Club
# 10954         73              Pescara
# 15631         70            Dijon FCO
# 4033          71       FC Midtjylland
# 13184         63   Defensa y Justicia
# 5751          70  Chamois Niortais FC

# %%
# Note: we could have also used drop command like df.drop(['col_names'],axis = 0)

# %%
df.shape
# Out:
# (17981, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Wage (€)     17981 non-null  int64
#  1   Value (€)    17981 non-null  int64
#  2   Name         17981 non-null  object
#  3   Age          17981 non-null  int64
#  4   Nationality  17981 non-null  object
#  5   Overall      17981 non-null  int64
#  6   Potential    17981 non-null  int64
#  7   Club         17733 non-null  object
# dtypes: int64(5), object(3)
# memory usage: 1.1+ MB

# %%
# we have a few missing values in the 'club' column

# %%
df = df.rename(columns={'Wage (€)':'Wage','Value (€)':'Value'})
#Desired Columns renamed

# %%
df
# Out:
#          Wage      Value               Name  Age Nationality  Overall  \
# 0      565000   95500000  Cristiano Ronaldo   32    Portugal       94
# 1      565000  105000000           L. Messi   30   Argentina       93
# 2      280000  123000000             Neymar   25      Brazil       92
# 3      510000   97000000          L. Suárez   30     Uruguay       92
# 4      230000   61000000           M. Neuer   31     Germany       92
# ...       ...        ...                ...  ...         ...      ...
# 17976    1000      50000          A. Kelsey   17     England       46
# 17977    1000          0      B. Richardson   47     England       46
# 17978    1000      60000           J. Young   17    Scotland       46
# 17979    1000      60000       J. Lundstram   18     England       46
# 17980    1000      50000          L. Sackey   18       Ghana       46
#
#        Potential                 Club
# 0             94       Real Madrid CF
# 1             93         FC Barcelona
# ...

# %%
# looking for missing values 
# Club has 248 missing values
df.isna().sum()
# Out:
# Wage             0
# Value            0
# Name             0
# Age              0
# Nationality      0
# Overall          0
# Potential        0
# Club           248
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    17929
# True        52
# dtype: int64

# %%
# following are the 52 duplicated data
df.loc[df.duplicated()]
# Out:
#       Wage     Value             Name  Age    Nationality  Overall  Potential  \
# 804  30000  11500000        D. Heintz   23        Germany       78         82
# 805  19000  13000000          Pozuelo   25          Spain       78         81
# 809  53000  13500000      M. Sabitzer   23        Austria       78         82
# 810  21000  11500000             Capa   25          Spain       78         83
# 815  54000  10500000      C. Aránguiz   28          Chile       78         78
# 816  24000  14000000       V. Rongier   22         France       78         84
# 818  95000  13000000       J. Lingard   24        England       78         80
# 820  45000   8000000     A. Marchesín   29      Argentina       78         79
# 822  95000  10500000           Danilo   25         Brazil       78         81
# 824  49000  10500000       O. Al Soma   28          Syria       78         78
# 826  22000  11000000            Bigas   26          Spain       78         81
# ...

# %%
# checking an example duplicate
df.query('Name == "D. Heintz"')
# Out:
#       Wage     Value       Name  Age Nationality  Overall  Potential  \
# 750  30000  11500000  D. Heintz   23     Germany       78         82
# 804  30000  11500000  D. Heintz   23     Germany       78         82
#
#            Club
# 750  1. FC Köln
# 804  1. FC Köln

# %%
# so we need to remove these duplicates , in order to do so we need the following:
df = df.loc[~df.duplicated(subset = ['Wage','Value','Name','Age','Nationality','Overall','Potential','Club'])]\
.reset_index(drop = True).copy()

# %%
df.sample(5)
# Out:
#         Wage    Value         Name  Age    Nationality  Overall  Potential  \
# 9644    3000   280000  N. Ferreira   35       Portugal       66         66
# 15527   6000   200000  G. Diangana   19        England       58         68
# 6206   16000  1300000     G. Evans   22        England       69         76
# 8591   17000   975000    R. Mirzov   24         Russia       67         70
# 9629    2000   400000      E. Bush   31  United States       66         66
#
#                   Club
# 9644           FC Thun
# 15527  West Ham United
# 6206           Reading
# 8591          FC Tosno
# 9629   Montreal Impact

# %%
# now we have 17929 unique player details across 8 features
df.shape
# Out:
# (17929, 8)

# %% [markdown]
# ## Feature Understanding ⚒️
# (Univariate Analysis)
#
# - Plotting Feature Distributions
#     - Histogram
#     - KDE
#     - Box plot

# %%
df['Nationality'].value_counts()
# we can see that most players are from England followed by Germany , Spain , France , Argentina etc.
# Out:
# England      1629
# Germany      1135
# Spain        1009
# France        973
# Argentina     961
#              ...
# Fiji            1
# Eritrea         1
# Guatemala       1
# Oman            1
# Hong Kong       1
# Name: Nationality, Length: 165, dtype: int64

# %%
#top 10 countries with count of players
ax = df['Nationality'].value_counts().head(10).sort_values()\
    .plot(kind = 'barh',title = 'Top 10 Countires along with number of players')
ax.set_xlabel('Number of Players')
ax.set_ylabel('Countries')
# Out:
# Text(0, 0.5, 'Countries')

# %% [markdown]
# So, Max. number of players are from the european continent, followed by South American continent and from Asia Japan made it to top 10

# %%
ax2 = df['Overall'].plot(kind = 'hist',bins = 10, title = 'Player Overall Rating Distribution')
ax2.set_xlabel('Overall Rating')
ax2.set_ylabel('Number of Players')
# its clear from the graph that maximum of the players have an overall rating ranging from 60 to 75 and
# very few players can reach higher and beyond 90 as those are the world's best namely Messi , Ronaldo, Neymar etc.
# Out:
# Text(0, 0.5, 'Number of Players')

# %%
# looking at the distribution through KDE (Kernel Density Estimate)

ax3 = df['Overall'].plot(kind = 'kde', title = 'Player Overall Rating Distribution',color = 'green')
ax3.set_xlabel('Overall Rating')
ax3.set_ylabel('Number of Players')
# Out:
# Text(0, 0.5, 'Number of Players')

# %%
ax2 =df.Overall.plot(kind = 'hist',bins = 10, title = 'Player Overall Rating Distribution',color='#72C1D5')
ax3=ax2.twinx()
ax3 = df.Overall.plot(kind = 'kde', title = 'Player Overall Rating Distribution',color = "midnightblue")

plt.show()

# %% [markdown]
# ## Feature Relationships 📊
# - Scatter Plot
# - Heatmap correlation
# - Pairplot
# - Groupby Comparisons

# %%
ax4 = df.plot(kind = 'scatter',x = 'Age',y = 'Wage', title = 'Player Age vs Wage')
plt.show()

# %% [markdown]
# ### How are Age, Wage and overall rating of a player reated to each other ?

# %%
# plotting it with seaborn for a better look and adding a bit more detail
ax5 = sns.scatterplot(x = 'Age',
                      y = 'Wage',
                      hue = 'Overall',
                      data = df)
ax5.set_title('Player Age vs Wage')
plt.show()

# %% [markdown]
# From the above plot it can be understood that , a player's overall rating is a determining factor for his wage as we can see the higher the potential the higher the wage is. </br>
# Also Players belonging to 25 to 35 age group receive the highest wage.

# %%
# lets compare multiple features together for any hidden relationships 
ax6 = sns.pairplot(df, vars = ['Wage','Value','Age','Overall','Potential'])
plt.show()

# %%
#finding out the correlation 
#df[['Wage','Value','Age','Overall','Potential']].dropna().corr().style.background_gradient('PuOr')

# %%
df_corr = df[['Wage','Value','Age','Overall','Potential']].dropna().corr()
sns.heatmap(df_corr, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Ask a question about the Data ❓
#
# For any given Overall rating (lets assume 80) does wage vary based on a player's Nationality ?

# %%
df[df['Overall']==80].groupby('Nationality')['Wage'].mean().sort_values()
# Out:
# Nationality
# Ukraine                  1000.000000
# Morocco                 23000.000000
# Sweden                  25000.000000
# Colombia                26000.000000
# Brazil                  28125.000000
# Portugal                30666.666667
# Denmark                 33000.000000
# Slovenia                33500.000000
# Chile                   34333.333333
# Ivory Coast             38000.000000
# Mexico                  38666.666667
# Nigeria                 40000.000000
# Ghana                   41000.000000
# Algeria                 42000.000000
# France                  45875.000000
# Guinea                  48000.000000
# Spain                   49333.333333
# Uzbekistan              50000.000000
# Argentina               51750.000000
# Canada                  56000.000000
# Germany                 56666.666667
# United States           57000.000000
# Cameroon                59000.000000
# Serbia                  60500.000000
# Poland                  62000.000000
# ...

# %%
ax = df[df['Overall']==80].groupby('Nationality')['Wage'].mean().sort_values().plot(kind = 'barh', figsize =(10,10), title = 'Player Average Wages based on Nationality')
ax.set_xlabel('Average salary in Euros')
plt.show()

# %% [markdown]
# ### Answer: 🕵️‍♂️
# From the above we can answer our question as follows: </br>
# Given a fixed overall rating of a player ,say 80 which basically means players of similar merit , we an see a huge <b> nationality biasing</b> as Republic of Ireland is receiving the most salary.  </br>
#
# Not necessarily Rep. of Ireland produces top grade players but given an overall rating of 80 Rep. of Ireland players get and average salary of 110000 euros followed by English players with an average of 99364 euros which is of ~10% difference
